# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load latency CSV (placeholder)
# Columnas esperadas: execution, latency_ms, replay_ms, cost_usd
df = pd.DataFrame(columns=['execution', 'latency_ms', 'replay_ms', 'cost_usd'])
df.head()
# Out:
# Empty DataFrame
# Columns: [execution, latency_ms, replay_ms, cost_usd]
# Index: []

# %%
# Plot replay overhead (placeholder)
plt.figure(figsize=(6, 4))
plt.plot([], [], label='Latency')      # datos vacíos
plt.plot([], [], label='Replay')
plt.title('Latency vs Replay Overhead')
plt.xlabel('Execution')
plt.ylabel('Time (ms)')
plt.legend()
plt.show()
